# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from models import (get_RF, get_DT, get_knn, get_SVC, get_GBC, get_MLP, run_classifier)
from helper_functions import (get_cv_performance_metrics, hr,\
     get_sampler, plot_confusion_matrices, plot_roc)
import pickle
from sklearn.feature_selection import mutual_info_classif, GenericUnivariateSelect

# %%
headers = ["duration", "wage increase first year", "wage increase second year", "wage increase third year",\
           "cost of living adjustment", "working hours", "pension", "standby pay", "shift differential",\
           "education allowance", "statutory holidays", "vacation", "longterm disability assistance",\
           "contribution to dental plan", "bereavement assistance", "contribution to health plan", 'negotiations']

# %%
train_labor_data = pd.read_csv('data/labor-neg.data', header=None, names=headers, na_values = "?")

# %%
train_labor_data.head()
# Out:
#    duration  wage increase first year  wage increase second year  \
# 0       1.0                       5.0                        NaN
# 1       2.0                       4.5                        5.8
# 2       NaN                       NaN                        NaN
# 3       3.0                       3.7                        4.0
# 4       3.0                       4.5                        4.5
#
#    wage increase third year cost of living adjustment  working hours  \
# 0                       NaN                       NaN           40.0
# 1                       NaN                       NaN           35.0
# 2                       NaN                       NaN           38.0
# 3                       5.0                        tc            NaN
# 4                       5.0                       NaN           40.0
#
#       pension  standby pay  shift differential education allowance  \
# 0         NaN          NaN                 2.0                 NaN
# 1    ret_allw          NaN                 NaN                 yes
# 2  empl_contr          NaN                 5.0                 NaN
# 3         NaN          NaN                 NaN                 yes
# 4         NaN          NaN                 NaN                 NaN
#
#    statutory holidays       vacation longterm disability assistance  \
# 0                11.0        average                            NaN
# 1                11.0  below average                            NaN
# 2                11.0       generous                            yes
# 3                 NaN            NaN                            NaN
# 4                12.0        average                            NaN
#
#   contribution to dental plan bereavement assistance  \
# 0                         NaN                    yes
# 1                        full                    NaN
# 2                        half                    yes
# 3                         NaN                    yes
# 4                        half                    yes
#
#   contribution to health plan negotiations
# 0                         NaN         good
# 1                        full         good
# 2                        half         good
# 3                         NaN         good
# 4                        half         good

# %%
test_labor_data = pd.read_csv('data/labor-neg.test', header=None, names=headers, na_values="?")

# %%
test_labor_data.head()
# Out:
#    duration  wage increase first year  wage increase second year  \
# 0         1                       4.0                        NaN
# 1         2                       2.0                        3.0
# 2         2                       2.5                        2.5
# 3         2                       2.5                        3.0
# 4         2                       4.0                        4.0
#
#    wage increase third year cost of living adjustment  working hours  \
# 0                       NaN                      none            NaN
# 1                       NaN                      none           38.0
# 2                       NaN                        tc           39.0
# 3                       NaN                       tcf           40.0
# 4                       NaN                      none           40.0
#
#       pension  standby pay  shift differential education allowance  \
# 0        none          NaN                 NaN                 yes
# 1  empl_contr          NaN                 NaN                 yes
# 2  empl_contr          NaN                 NaN                 NaN
# 3        none          NaN                 NaN                 NaN
# 4        none          NaN                 3.0                 NaN
#
#    statutory holidays       vacation longterm disability assistance  \
# 0                11.0        average                             no
# 1                12.0       generous                            yes
# 2                12.0        average                            NaN
# 3                11.0  below average                            NaN
# 4                10.0  below average                             no
#
#   contribution to dental plan bereavement assistance  \
# 0                        none                     no
# 1                        none                    yes
# 2                         NaN                    yes
# 3                         NaN                    yes
# 4                        none                    NaN
#
#   contribution to health plan negotiations
# 0                        none          bad
# 1                        full          bad
# 2                         NaN          bad
# 3                         NaN          bad
# 4                        none          bad

# %% [markdown]
# Let us handle the Null values now

# %%
train_labor_data['wage increase third year']..isna().sum()()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40 entries, 0 to 39
# Series name: wage increase third year
# Non-Null Count  Dtype
# --------------  -----
# 12 non-null     float64
# dtypes: float64(1)
# memory usage: 448.0 bytes
